# %% [markdown]
# # Oktoberfest Ratings
#
# I'll update this graph as I try different beers!
# The graph ordering is random so I rerun this until I get a layout I like.

# %%
from functools import reduce

import matplotlib.pyplot as plt
import networkx as nx

# %%
import networkx as nx
import matplotlib.pyplot as plt
from collections import Counter

edges = [
    ("Robert Morris", "Pittsburgh"),
    ("Oregon", "Notre Dame"),
    ("Columbia", "Duke"),
    ("Saint Joseph's", "Michigan"),
    ("Creighton", "Iowa State"),
    ("Duke", "Ohio State"),
    ("North Carolina", "Louisville"),
    ("Stanford", "UCLA"),
    ("Texas", "LSU"),
]

# Compute edge weights
edge_weights = Counter(edges)

# Build graph
G = nx.DiGraph()
for (src, dst), weight in edge_weights.items():
    G.add_edge(src, dst, weight=weight)

# Draw the graph
plt.figure(figsize=(12, 8))
pos = nx.spring_layout(G, k=0.5, seed=42)
edge_labels = nx.get_edge_attributes(G, 'weight')

nx.draw(
    G,
    pos,
    with_labels=True,
    node_color="skyblue",
    node_size=2000,
    font_size=10,
    font_weight='bold',
    arrows=True,
    edge_color="gray",
    width=[G[u][v]['weight'] for u, v in G.edges()],
)

nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)

plt.title("Women's Basketball Transfers (2025)", fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/jg/pzxyc9d57qs14dktxjrz_wnr0000gn/T/ipykernel_22719/745893445.py:46: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
